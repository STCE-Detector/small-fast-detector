# %%
import pygad
import numpy as np

# %%
ga_instance = pygad.load(filename='/Users/inaki-eab/Desktop/small-fast-detector/tracker/finetune/outputs/studies/byte_mot20_1715200179.747547')

# %%
print(ga_instance.summary())
# Out:
# ----------------------------------------------------------------------
#                            PyGAD Lifecycle
# ...
# Step                   Handler                            Output Shape
# ...
# Fitness Function       fitness_fn()                       (1)
# ----------------------------------------------------------------------
# Parent Selection       steady_state_selection()           (2, 19)
# Number of Parents: 2
# ----------------------------------------------------------------------
# Crossover              uniform_crossover()                (2, 19)
# Crossover probability: 0.5
# ----------------------------------------------------------------------
# Mutation               adaptive_mutation()                (2, 19)
# Mutation Probability: [0.25, 0.1]
# Mutation Percentage: default
# Mutation Genes: None
# Random Mutation Range: (-1.0, 1.0)
# ...

# %%
# Returning the details of the best solution.
solution, solution_fitness, solution_idx = ga_instance.best_solution(ga_instance.last_generation_fitness)
print(f"Parameters of the best solution : \n{list(np.round(np.array(solution, dtype=float), decimals=2))}")
print(f"Fitness value of the best solution = {solution_fitness}")
print(f"Index of the best solution : {solution_idx}")
if ga_instance.best_solution_generation != -1:
    print(f"Best fitness value reached after {ga_instance.best_solution_generation} generations.")
# Out:
# Parameters of the best solution :
# [0.49, 0.14, 0.13, 0.67, 0.71, 0.72, 0.08, 0.11, 0.34, 0.0, 0.0, 1.0, 0.0, 5.0, 1.0, 0.88, 0.0, 131.0, 361.0]
# Fitness value of the best solution = 41.014
# Index of the best solution : 0
# Best fitness value reached after 26 generations.

# %%
ga_instance.plot_fitness()
None
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
ga_instance.plot_genes()
None

# %%
ga_instance.plot_new_solution_rate()
None
